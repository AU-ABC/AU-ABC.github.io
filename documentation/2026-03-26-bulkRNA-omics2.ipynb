# %% [markdown]
# ---
# title: "OMICS workshop II"
# authors:
#   - name: "Mohammed N Hassan"
#     role: "Teaching and material creation"
#   - name: "Samuele Soraggi"
#     role: "Organization and assistance"
# image: ../img/news/omicsII_workshop.png
# date: 2026-03-26
# categories: [R, tidyverse, RNA, bash, alignment, visualization]
# description: "Second omics workshop building on the foundation of R and tidyverse for the analysis of omics data. We will cover preprocessing and downstream analysis topics."
# eval: false
# ---
#
# # Slides
#
# The slides for the workshop can be downloaded at the link below. They are in pdf format and contain the main points of the workshop.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-03-26-bulkRNA-omicsws2/ABC_OMICSII_bulkRNA.pdf" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Download Slides </a>
#
# </p>
#
# &nbsp;
#
# # Hands on Tutorial
#
# Material for the workshop can be downloaded at the links below. You can choose between html format or R markdown format.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-03-26-bulkRNA-omicsws2/ABC_OMICSII_bulkRNA.Rmd.txt" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Download Rmd </a>
#
# </p>
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-03-26-bulkRNA-omicsws2/ABC_OMICSII_bulkRNA.html" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Download html </a>
#
# </p>
#
# &nbsp;
#
# The html link for the tutorial is also useful as a reference without running all the code.
#
# # Evaluation
#
# Please leave us a feedback to improve this workshop in future.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdVURN_Jim7EOWP6UsCTSY2cbTgbxCuRXkdhiu2g5Bnhn_u9A/viewform?usp=header" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Feedback </a>
#
# </p>
#
# &nbsp;
