# %% [markdown]
# ---
# title: "OMICS workshop III"
# authors:
#   - name: "Mohammed N Hassan"
#     role: "Teaching and material creation"
#   - name: "Samuele Soraggi"
#     role: "Organization and assistance"
# image: ../img/news/omicsIII_workshop.png
# date: 2026-04-23
# categories: [scRNA-seq, omics, workshop]
# description: "Third omics workshop building on the foundation of R and tidyverse for the analysis of omics data. We will cover preprocessing and downstream analysis topics."
# eval: false
# ---
#
# # Slides and comands
#
# The slides and commands for the workshop can be downloaded at the link below.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-04-23-omicsws3/scRNA_workshop.zip" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Download </a>
#
# </p>
#
# &nbsp;
#
# # Evaluation
#
# Please leave us a feedback to improve this workshop in future.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdVURN_Jim7EOWP6UsCTSY2cbTgbxCuRXkdhiu2g5Bnhn_u9A/viewform?usp=header" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Feedback </a>
#
# </p>
#
# &nbsp;
