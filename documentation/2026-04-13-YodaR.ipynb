# %% [markdown]
# ---
# title: "Import and plot data in R"
# authors:
#   - name: "Samuele Soraggi"
#     role: "Teaching and material creation"
#   - name: "Silvia Turchetto"
#     role: "Organization and assistance"
# image: 2026-04-13-yoda-R/lifeExp.png
# date: 2026-04-13
# categories: [R, tidyverse, ggplot]
# description: "Young DANDRITE association introduction workshop to R and ggplot"
# eval: false
# ---
#
# # Material for the workshop exercise
#
# The material is in a zipped file which has the data and Rmd file.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-04-13-yoda-R/DGE.zip" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Download Material </a>
#
# </p>
#
# &nbsp;
#
# # Code rendered as webpage
#
# The rendered code with results printed out can always be consulted online as a reference
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-04-13-yoda-R/YodaPlotWorkshop.nb.html" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Rendered code </a>
#
# </p>
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-03-26-bulkRNA-omicsws2/ABC_OMICSII_bulkRNA.html" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Download html </a>
#
# </p>
#
# &nbsp;
#
# # Evaluation
#
# Please leave us a feedback to improve this workshop in future.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdVURN_Jim7EOWP6UsCTSY2cbTgbxCuRXkdhiu2g5Bnhn_u9A/viewform?usp=header" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Feedback </a>
#
# </p>
#
# &nbsp;
