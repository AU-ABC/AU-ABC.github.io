# %% [markdown]
# ---
# title: "OMICS workshop I"
# authors:
#   - name: "Mohammed N Hassan"
#     role: "Teaching and material creation"
#   - name: "Samuele Soraggi"
#     role: "Organization and assistance"
# image: ../img/Rlogo.png
# date: 2026-02-26
# categories: [R, tidyverse, omics, workshop]
# description: "First omics workshop laying the foundation of R and tidyverse for the analysis of omics data. We will cover the basics of R and tidyverse which come in handy for all omics analysis."
# eval: false
# ---
#
# # Slides
#
# Zip file with material for the workshop can be downloaded at the link below. It contains the workshop in html format or in R markdown format, as well as data files.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-02-26-tidyR-omicsws1/R_workshop_material.zip" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Download Material </a>
#
# </p>
#
# &nbsp;
#
# If you want only to read the tutorial without downloading the material, but just as a reference, you can click on the link below.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-02-26-tidyR-omicsws1/2026-02-26-tidyR-omics1.nb.html" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Read-only version </a>
#
# </p>
#
# &nbsp;
#
# # Exercise
#
# Now that you have gone through the tutorial, you can try to solve the exercise below. The exercise is designed to test your understanding of R and tidyverse and to give you some practice with the tools you have learned. Come to our next cafe to discuss the exercise and share your solutions !!!
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-02-26-tidyR-omicsws1/2026-02-26-tidyR-omics1-exercise.html" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Open exercise </a>
#
# </p>
#
# &nbsp;
#
# # Exercise solutions
#
# Got stuck? Solutions are down here.
#
# &nbsp;
#
# <p align="center">
#
# <a href="https://abc.au.dk/documentation/2026-02-26-tidyR-omicsws1/2026-02-26-tidyR-omics1-solutions.html" style="background-color: #4266A1; color: #FFFFFF; padding: 30px 20px; text-decoration: none; border-radius: 5px;"> Open exercise solutions </a>
#
# </p>
#
# &nbsp;
